# %%
import matplotlib.pyplot as plt

# %%
x1 = ['July','August','September']
y1 = [9443.75,9467.67,9478.08]
plt.plot(x1, y1)
plt.plot()
# Out:
# []

# %%
plt.bar(x1,y1)
plt.ylim(9400,9500)
# Out:
# (9400.0, 9500.0)

# %%
x2 = ['July','August','September']
y2 = [43982.85,44437.55,45605.33]
plt.plot(x2, y2)
plt.plot()
# Out:
# []

# %%
plt.bar(x2,y2)
plt.ylim(43000,46000)
# Out:
# (43000.0, 46000.0)

# %%
x3 = ['July','August','September']
y3 = [36337.72,36567.73,35780.83]
plt.plot(x3, y3)
plt.plot()
# Out:
# []

# %%
plt.bar(x3,y3)
plt.ylim(35000,37000)
# Out:
# (35000.0, 37000.0)
