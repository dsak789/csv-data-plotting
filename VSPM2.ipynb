# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
df2 = pd.read_excel("fsn_data_2020_08.XLSX")
df2
# Out:
#        MRP Cont   MATERIAL Material Type MRP Controller Section FSN ind  \
# 0         921.0  3801813.0          ZREF            RED     GEN       F
# 1         959.0  3800751.0          ZREF           SMS2     GEN       F
# 2         942.0  3800723.0          ZREF           SMS1     GEN       F
# 3         921.0  3800279.0          ZREF            RED     GEN       F
# 4         942.0  3030788.0          HIBE           SMS1     RM1       S
# ...         ...        ...           ...            ...     ...     ...
# 57670     959.0  3026096.0          HIBE           SMS2     RM1       F
# 57671     902.0  3009025.0          HIBE        SMD M-2     GEN       F
# 57672     938.0  3023872.0          HIBE    GENL-NON AR     GEN       F
# 57673     959.0  2083556.0          ERSA           SMS2     OPR       F
# 57674       NaN        NaN           NaN            NaN     NaN     NaN
#
#                                          DESCR.  UOM       Cl.MAP  Cl.Stock  \
# 0        REFMAGNASIA,MGO-C,SUPP&APPL,2500 HEATS  SET  35711484.34     1.000
# 1       TOTAL OPERATIONAL REFRACTORY MANAGEMENT   EA     12286.04  2800.000
# 2        TUNDISH REFRACTORY MANAGEMENT FOR SMS1   EA    103145.82   534.000
# 3      STL REF U/TLM,SMS-1,95HT GUARNTY,SUP/APP  SET   2589639.26     8.000
# 4      WIRE,RND,FERRO CALCIUM,13±0.5 mm,BY COIL   TO    110050.00   124.167
# ...                                         ...  ...          ...       ...
# 57670                   Synthetic slag,10-30 mm   TO     17528.84  1456.787
# 57671         BELT,CONV,M24,1200MM,1000/4,6X2MM    M      3706.10  8996.000
# 57672   STEEL STRAP (BLACK IN COLOUR) FOR STRAP   TO     87152.90   806.640
# 57673               TUBE,COPPER,1000MM, 150 SQ.   EA    272539.12   132.000
# 57674                                       NaN  NaN          NaN       NaN
#
#          Op.Value      Cl.Value
# 0        0.000000    357.114843
# 1        0.000000    344.009066
# 2      312.748931    550.798653
# 3        0.000000    207.171141
# 4        0.000000    136.645783
# ...           ...           ...
# 57670  365.582491    255.357932
# 57671  481.644564    333.400623
# 57672  909.269710    703.010167
# 57673  711.327110    359.751642
# 57674         NaN  76635.437468
#
# [57675 rows x 12 columns]

# %%
grouped = df2.groupby('MRP Controller')

group_dataframes = []
for group_name, group_df in grouped:
    group_dataframes.append(group_df)

sum_values = []
for group_df in group_dataframes:
    sum_values.append((group_df['Cl.Value'].sum()))

result_df = pd.DataFrame({'MRP_Controller': grouped.groups.keys(), 'Cl.Value': sum_values})

print(result_df)
# Out:
#      MRP_Controller     Cl.Value
# 0         ACS DEPTT   275.573020
# 1              AR-1   456.883405
# 2              AR-2   897.923860
# 3              AR-3   826.422063
# 4              AR-4   389.611423
# 5                BF  5654.637488
# 6       Blank MRP-C  1000.474981
# 7               CCP   202.004352
# 8               CED    62.048605
# 9               CME     0.357905
# 10               CO  1188.369693
# 11              CRG  2060.803937
# 12             CRMP   374.318111
# 13              DNW   389.399734
# 14              EMD   266.996952
# 15              ERS    92.427324
# 16               ES   419.000097
# 17              ETL    74.576490
# 18             EnMD   112.136425
# 19             FDRY     5.279704
# 20              FMD   525.837478
# 21      GENL-NON AR  9467.670361
# 22  INSTRUMENTATION   549.614575
# 23               IT    16.333971
# 24              L&H  1098.859125
# 25             LMMM   992.983673
# 26             MMSM   959.466319
# 27               PD     8.542835
# 28          QA & TD     5.390870
# 29              R&D     1.503760
# 30              RED  7238.081729
# 31             RMHP  1648.615278
# 32            RS&RS  1570.724428
# 33              SBM  1119.855953
# 34          SMD E-1    58.794685
# 35          SMD E-2   276.994497
# 36          SMD E-3   820.649747
# 37          SMD M-1  2872.573177
# 38          SMD M-2  2543.811437
# 39          SMD M-3  1344.550202
# 40      SMD-NON CBP   129.690895
# 41             SMS1  7330.818129
# 42             SMS2  7692.768015
# 43               SP  3807.538713
# 44   SPARES-NON SMD   835.157918
# 45             STED    32.148693
# 46              STM  1305.400335
# 47          TELECOM   130.070234
# 48              TPP  2008.001294
# 49            TRAFF   969.617820
# 50               TS     0.007308
# 51             UTIL   776.591956
# 52              WMD   308.812801
# 53            WRM-2  2180.753847
# 54             WRM1  1257.959842

# %%
cont=result_df['MRP_Controller']
cl= result_df['Cl.Value']

plt.figure(figsize=(30,15))
plt.pie(cl,labels=cont,autopct="%.1f%%")
plt.show()

# %%
grouped = df2.groupby('Material Type')

group_dataframes = []
for group_name, group_df in grouped:
    group_dataframes.append(group_df)

sum_values = []
for group_df in group_dataframes:
    sum_values.append((group_df['Cl.Value'].sum()))

result_df1 = pd.DataFrame({'Material_type': grouped.groups.keys(), 'Cl.Value': sum_values})

print(result_df1)
# Out:
#   Material_type      Cl.Value
# 0          ERSA  44437.556619
# 1          HIBE  17794.260787
# 2          ZCAP     92.407923
# 3          ZFMD    542.824317
# 4          ZREF  13768.387823

# %%
mtype=result_df1['Material_type']
cl= result_df1['Cl.Value']

plt.figure(figsize=(20,10))
plt.pie(cl,labels=mtype,autopct="%.1f%%")
plt.show()

# %%
grouped = df2.groupby('Section')

group_dataframes = []
for group_name, group_df in grouped:
    group_dataframes.append(group_df)

sum_values = []
for group_df in group_dataframes:
    sum_values.append((group_df['Cl.Value'].sum()))

result_df2 = pd.DataFrame({'Section': grouped.groups.keys(), 'Cl.Value': sum_values})

print(result_df2)
# Out:
#   Section      Cl.Value
# 0     ELE   4699.254041
# 1     GEN  36567.739090
# 2     MEC  26036.977615
# 3     OPR   8484.317383
# 4     RM1    847.149340

# %%
section=result_df2['Section']
cl= result_df2['Cl.Value']

plt.figure(figsize=(20,10))
plt.pie(cl,labels=section,autopct="%.1f%%")
plt.show()
